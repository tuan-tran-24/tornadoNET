# %% [markdown]
# # Data Statistics

# %% [markdown]
# ## Import

# %%
from data_stats import plot_counts

# %% [markdown]
# ## Implementation

# %%
recovery_states = ["Uninhabited", "Empty", "Rebuilding", "Rebuilt"]

# %% [markdown]
# ### Total Dataset

# %%
roots = [
    ("2011", r"C:\Albert\Dr. Koliou Research\Labeled\2011"),
    ("2012", r"C:\Albert\Dr. Koliou Research\Labeled\2012"),
    ("2013", r"C:\Albert\Dr. Koliou Research\Labeled\2013"),
    ("2014", r"C:\Albert\Dr. Koliou Research\Labeled\2014"),
    ("2015", r"C:\Albert\Dr. Koliou Research\Labeled\2015"),
    ("2016", r"C:\Albert\Dr. Koliou Research\Labeled\2016"),
]

plot_counts(
    roots,
    recovery_states=recovery_states,
    save_path=None,
    title="Total Dataset",
)

# %% [markdown]
# ### Training Set

# %%
roots = [
    ("2011", r"C:\Albert\Dr. Koliou Research\Train\Train 2011"),
    ("2012", r"C:\Albert\Dr. Koliou Research\Train\Train 2012"),
    ("2013", r"C:\Albert\Dr. Koliou Research\Train\Train 2013"),
    ("2014", r"C:\Albert\Dr. Koliou Research\Train\Train 2014"),
    ("2015", r"C:\Albert\Dr. Koliou Research\Train\Train 2015"),
    ("2016", r"C:\Albert\Dr. Koliou Research\Train\Train 2016"),
]

plot_counts(
    roots,
    recovery_states=recovery_states,
    save_path=None,
    title="Training Set",
)

# %% [markdown]
# ### Validation Set

# %%
roots = [
    ("2011", r"C:\Albert\Dr. Koliou Research\Validation\Validation 2011"),
    ("2012", r"C:\Albert\Dr. Koliou Research\Validation\Validation 2012"),
    ("2013", r"C:\Albert\Dr. Koliou Research\Validation\Validation 2013"),
    ("2014", r"C:\Albert\Dr. Koliou Research\Validation\Validation 2014"),
    ("2015", r"C:\Albert\Dr. Koliou Research\Validation\Validation 2015"),
    ("2016", r"C:\Albert\Dr. Koliou Research\Validation\Validation 2016"),
]

plot_counts(
    roots,
    recovery_states=recovery_states,
    save_path=None,
    title="Validation Set",
)
